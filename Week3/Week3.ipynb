# %% [markdown]
# <a href="https://colab.research.google.com/github/MakaylaStephens-byte/ThinkPythonAssignments/blob/main/Week3/Week3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import Statements

# Function Definitions

# Program logic
# Assign vaules to: name, goal, birth_year, and current_year
# Calculate age
# Print top boarder
# Print bio sentence
# Print bottom boarder
