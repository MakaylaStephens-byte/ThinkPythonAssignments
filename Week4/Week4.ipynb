# %% [markdown]
# <a href="https://colab.research.google.com/github/MakaylaStephens-byte/ThinkPythonAssignments/blob/main/Week4/Week4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORT STATEMENTS
# (None)

# FUNCTION DEFINITIONS
# 1. Define print_bio with three parameters: name, age, and goal.
def print_bio( name, age, goal):

# 2. Inside the function, use string multiplication (*) for a border line.
    print( '*' * 25 )

# 3. Print the bio details using the parameter names.
    print( "Name: " + name + ", Age: " + str(age) + ", Goal: " + goal  )
    print( '*' * 25 )


# PROGRAM LOGIC
# 1. Call print_bio using my own info.
print_bio('Makayla', 23, 'to Learn Coding')
print()
# 2. Call print_bio using [Name of Famous Person].
print_bio('Isaac Newton ', 44, 'Discover Gravity' )
print()
# 3. Call print_bio using [Name of Fictional Character].
print_bio('Naruto', 16, 'To Become Hokage' )
print()
# Out:
# *************************
# Name: Makayla, Age: 23, Goal: to Learn Coding
# *************************
#
# *************************
# Name: Isaac Newton , Age: 44, Goal: Discover Gravity
# *************************
#
# *************************
# Name: Naruto, Age: 16, Goal: To Become Hokage
# *************************
